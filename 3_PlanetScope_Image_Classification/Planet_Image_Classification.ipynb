# %% [markdown]
# ## Installing Required Packages

# %%
# !pip install earthpy
# !pip install plotly
# !pip install openpyxl
# !pip install rasterio
# !pip install fiona
# !pip install geopandas
# !pip install spyndex
# !pip install rioxarray
# !pip install xarray
# !pip install shap
# !pip install tqdm
# !pip install imbalanced-learn
# !pip install --upgrade xgboost
# !pip install ipympl
# !pip install feature-engine
# Out:
# Collecting earthpy
#   Using cached earthpy-0.9.4-py3-none-any.whl (1.4 MB)
# Requirement already satisfied: scikit-image in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthpy) (0.19.3)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthpy) (2.28.1)
# Requirement already satisfied: numpy>=1.14.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthpy) (1.22.4)
# Requirement already satisfied: geopandas in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthpy) (0.11.1)
# Requirement already satisfied: rasterio in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthpy) (1.3.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthpy) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (4.37.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (2.7.5)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (9.2.0)
# Requirement already satisfied: pandas>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas->earthpy) (1.4.2)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas->earthpy) (3.4.0)
# Requirement already satisfied: shapely<2,>=1.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas->earthpy) (1.8.4)
# Requirement already satisfied: fiona>=1.8 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas->earthpy) (1.8.21)
# Requirement already satisfied: snuggs>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio->earthpy) (1.4.7)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio->earthpy) (2022.9.14)
# Requirement already satisfied: attrs in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio->earthpy) (22.1.0)
# Requirement already satisfied: click-plugins in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio->earthpy) (1.1.1)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio->earthpy) (8.1.3)
# Requirement already satisfied: affine in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio->earthpy) (2.3.1)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio->earthpy) (65.3.0)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio->earthpy) (0.7.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthpy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthpy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->earthpy) (1.26.11)
# Requirement already satisfied: PyWavelets>=1.1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-image->earthpy) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-image->earthpy) (2.21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-image->earthpy) (2022.8.12)
# Requirement already satisfied: networkx>=2.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-image->earthpy) (2.8.6)
# Requirement already satisfied: scipy>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-image->earthpy) (1.9.1)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas->earthpy) (2.5.0)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas->earthpy) (1.16.0)
# Collecting python-dateutil>=2.7
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas->earthpy) (2022.2.1)
# Installing collected packages: python-dateutil, earthpy
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.7.5
#     Uninstalling python-dateutil-2.7.5:
#       Successfully uninstalled python-dateutil-2.7.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cmip6-preprocessing 0.6.0 requires pint-xarray, which is not installed.
# sat-stac 0.4.1 requires python-dateutil~=2.7.5, but you have python-dateutil 2.8.2 which is incompatible.
# intake-esm 2021.8.17 requires h5netcdf>=0.8.1, but you have h5netcdf 0.0.0 which is incompatible.
# cmip6-preprocessing 0.6.0 requires xgcm<0.7.0, but you have xgcm 0.8.0 which is incompatible.
# Successfully installed earthpy-0.9.4 python-dateutil-2.8.2
# Collecting plotly
#   Downloading plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 38.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly) (8.0.1)
# Installing collected packages: plotly
# Successfully installed plotly-5.13.1
# Collecting openpyxl
#   Using cached openpyxl-3.1.1-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.1
# Requirement already satisfied: rasterio in /srv/conda/envs/notebook/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: snuggs>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: numpy>=1.18 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (1.22.4)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (8.1.3)
# Requirement already satisfied: attrs in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (22.1.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (65.3.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (2022.9.14)
# Requirement already satisfied: affine in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio) (2.3.1)
# Requirement already satisfied: pyparsing>=2.1.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Requirement already satisfied: fiona in /srv/conda/envs/notebook/lib/python3.10/site-packages (1.8.21)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona) (8.1.3)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona) (65.3.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona) (2022.9.14)
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona) (22.1.0)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona) (0.7.2)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona) (2.5.0)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona) (1.1.1)
# Requirement already satisfied: geopandas in /srv/conda/envs/notebook/lib/python3.10/site-packages (0.11.1)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (3.4.0)
# Requirement already satisfied: shapely<2,>=1.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (1.8.4)
# Requirement already satisfied: pandas>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: fiona>=1.8 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopandas) (21.3)
# Requirement already satisfied: six>=1.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (8.1.3)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (2022.9.14)
# Requirement already satisfied: attrs>=17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (22.1.0)
# Requirement already satisfied: munch in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click-plugins>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (65.3.0)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (2022.2.1)
# Requirement already satisfied: numpy>=1.21.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (1.22.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from packaging->geopandas) (3.0.9)
# Collecting spyndex
#   Using cached spyndex-0.3.0-py3-none-any.whl
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.10/site-packages (from spyndex) (1.4.2)
# Requirement already satisfied: requests in /srv/conda/envs/notebook/lib/python3.10/site-packages (from spyndex) (2.28.1)
# Requirement already satisfied: seaborn in /srv/conda/envs/notebook/lib/python3.10/site-packages (from spyndex) (0.12.0)
# Collecting eemont>=0.3.6
#   Using cached eemont-0.3.6-py3-none-any.whl
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from spyndex) (1.22.4)
# Requirement already satisfied: xarray in /srv/conda/envs/notebook/lib/python3.10/site-packages (from spyndex) (2022.6.0)
# Requirement already satisfied: matplotlib in /srv/conda/envs/notebook/lib/python3.10/site-packages (from spyndex) (3.5.3)
# Requirement already satisfied: dask>=2021.9.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from spyndex) (2022.8.0)
# Requirement already satisfied: python-box>=6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from spyndex) (6.0.2)
# Collecting earthengine-api
#   Downloading earthengine-api-0.1.343.tar.gz (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.7/245.7 kB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fsspec>=0.6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dask>=2021.9.1->spyndex) (2022.8.2)
# Requirement already satisfied: toolz>=0.8.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dask>=2021.9.1->spyndex) (0.12.0)
# Requirement already satisfied: partd>=0.3.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dask>=2021.9.1->spyndex) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dask>=2021.9.1->spyndex) (2.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dask>=2021.9.1->spyndex) (5.4.1)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dask>=2021.9.1->spyndex) (21.3)
# Requirement already satisfied: beautifulsoup4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from eemont>=0.3.6->spyndex) (4.11.1)
# Collecting ee-extra>=0.0.15
#   Using cached ee_extra-0.0.15-py3-none-any.whl
# Requirement already satisfied: geopy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from eemont>=0.3.6->spyndex) (2.2.0)
# Requirement already satisfied: google-cloud-storage in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api->spyndex) (2.5.0)
# Collecting google-api-python-client>=1.12.1
#   Downloading google_api_python_client-2.80.0-py2.py3-none-any.whl (11.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 51.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: google-auth>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from earthengine-api->spyndex) (2.11.0)
# Collecting google-auth-httplib2>=0.0.3
#   Using cached google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting httplib2<1dev,>=0.9.2
#   Using cached httplib2-0.21.0-py3-none-any.whl (96 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->spyndex) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->spyndex) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->spyndex) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->spyndex) (4.37.2)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->spyndex) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib->spyndex) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas->spyndex) (2022.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->spyndex) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->spyndex) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->spyndex) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from requests->spyndex) (3.3)
# Collecting uritemplate<5,>=3.0.1
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-python-client>=1.12.1->earthengine-api->spyndex) (2.10.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api->spyndex) (4.7.2)
# Requirement already satisfied: six>=1.9.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api->spyndex) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api->spyndex) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-auth>=1.4.1->earthengine-api->spyndex) (0.2.7)
# Requirement already satisfied: locket in /srv/conda/envs/notebook/lib/python3.10/site-packages (from partd>=0.3.10->dask>=2021.9.1->spyndex) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from beautifulsoup4->eemont>=0.3.6->spyndex) (2.3.2.post1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from geopy->eemont>=0.3.6->spyndex) (1.52)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api->spyndex) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-cloud-storage->earthengine-api->spyndex) (2.3.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->spyndex) (1.56.4)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.20.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api->spyndex) (3.20.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api->spyndex) (1.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api->spyndex) (0.4.8)
# Requirement already satisfied: cffi>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api->spyndex) (1.15.1)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.10/site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api->spyndex) (2.21)
# Building wheels for collected packages: earthengine-api
#   Building wheel for earthengine-api (setup.py) ... done
#   Created wheel for earthengine-api: filename=earthengine_api-0.1.343-py3-none-any.whl size=275059 sha256=aad4f89c38367ad8ba49bc2486e6f2bf5f9efb0effa6d28f9e47fc805577cfeb
#   Stored in directory: /home/jovyan/.cache/pip/wheels/34/a3/6a/facd91ebadee99a5e8323d616a44e7ed21c2ea9368e5e2fbe8
# Successfully built earthengine-api
# Installing collected packages: uritemplate, httplib2, google-auth-httplib2, google-api-python-client, earthengine-api, ee-extra, eemont, spyndex
# Successfully installed earthengine-api-0.1.343 ee-extra-0.0.15 eemont-0.3.6 google-api-python-client-2.80.0 google-auth-httplib2-0.1.0 httplib2-0.21.0 spyndex-0.3.0 uritemplate-4.1.1
# Requirement already satisfied: rioxarray in /srv/conda/envs/notebook/lib/python3.10/site-packages (0.12.1)
# Requirement already satisfied: xarray>=0.17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rioxarray) (2022.6.0)
# Requirement already satisfied: rasterio>=1.1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rioxarray) (1.3.2)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rioxarray) (21.3)
# Requirement already satisfied: pyproj>=2.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rioxarray) (3.4.0)
# Requirement already satisfied: certifi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyproj>=2.2->rioxarray) (2022.9.14)
# Requirement already satisfied: click-plugins in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (1.1.1)
# Requirement already satisfied: snuggs>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (1.4.7)
# Requirement already satisfied: numpy>=1.18 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (1.22.4)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (65.3.0)
# Requirement already satisfied: attrs in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (22.1.0)
# Requirement already satisfied: click>=4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (0.7.2)
# Requirement already satisfied: affine in /srv/conda/envs/notebook/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from xarray>=0.17->rioxarray) (1.4.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from packaging->rioxarray) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.2->xarray>=0.17->rioxarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.2->xarray>=0.17->rioxarray) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.2->xarray>=0.17->rioxarray) (1.16.0)
# Requirement already satisfied: xarray in /srv/conda/envs/notebook/lib/python3.10/site-packages (2022.6.0)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from xarray) (21.3)
# Requirement already satisfied: pandas>=1.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from xarray) (1.4.2)
# Requirement already satisfied: numpy>=1.19 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from xarray) (1.22.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from packaging>=20.0->xarray) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.2->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.2->xarray) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.2->xarray) (1.16.0)
# Collecting shap
#   Using cached shap-0.41.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (572 kB)
# Requirement already satisfied: pandas in /srv/conda/envs/notebook/lib/python3.10/site-packages (from shap) (1.4.2)
# Requirement already satisfied: cloudpickle in /srv/conda/envs/notebook/lib/python3.10/site-packages (from shap) (2.2.0)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from shap) (1.9.1)
# Requirement already satisfied: numba in /srv/conda/envs/notebook/lib/python3.10/site-packages (from shap) (0.55.2)
# Requirement already satisfied: scikit-learn in /srv/conda/envs/notebook/lib/python3.10/site-packages (from shap) (1.1.2)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from shap) (1.22.4)
# Requirement already satisfied: tqdm>4.25.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from shap) (4.64.1)
# Requirement already satisfied: packaging>20.9 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from shap) (21.3)
# Collecting slicer==0.0.7
#   Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.10/site-packages (from numba->shap) (65.3.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from numba->shap) (0.38.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas->shap) (2022.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn->shap) (1.2.0)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.41.0 slicer-0.0.7
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.10/site-packages (4.64.1)
# Collecting imbalanced-learn
#   Using cached imbalanced_learn-0.10.1-py3-none-any.whl (226 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from imbalanced-learn) (3.1.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from imbalanced-learn) (1.1.2)
# Requirement already satisfied: numpy>=1.17.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: joblib>=1.1.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from imbalanced-learn) (1.9.1)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.10.1
# Collecting xgboost
#   Using cached xgboost-1.7.4-py3-none-manylinux2014_x86_64.whl (193.6 MB)
# Requirement already satisfied: scipy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from xgboost) (1.9.1)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from xgboost) (1.22.4)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.4
# Collecting ipympl
#   Using cached ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
# Requirement already satisfied: numpy in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipympl) (1.22.4)
# Requirement already satisfied: ipython-genutils in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipympl) (9.2.0)
# Requirement already satisfied: ipython<9 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipympl) (8.5.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipympl) (7.7.1)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipympl) (3.5.3)
# Requirement already satisfied: traitlets<6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipympl) (5.4.0)
# Requirement already satisfied: pexpect>4.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: backcall in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (2.13.0)
# Requirement already satisfied: stack-data in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (0.5.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (3.0.31)
# Requirement already satisfied: jedi>=0.16 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.15.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.37.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: psutil in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.2.2)
# Requirement already satisfied: pyzmq>=17 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (24.0.0)
# Requirement already satisfied: debugpy>=1.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.3)
# Requirement already satisfied: tornado>=6.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1)
# Requirement already satisfied: nest-asyncio in /srv/conda/envs/notebook/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /srv/conda/envs/notebook/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.4.12)
# Requirement already satisfied: executing in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (1.0.0)
# Requirement already satisfied: asttokens in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (2.0.8)
# Requirement already satisfied: pure-eval in /srv/conda/envs/notebook/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: entrypoints in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: argon2-cffi in /srv/conda/envs/notebook/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.15.0)
# Requirement already satisfied: jinja2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (3.1.2)
# Requirement already satisfied: nbconvert>=5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (6.5.3)
# Requirement already satisfied: prometheus-client in /srv/conda/envs/notebook/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.14.1)
# Requirement already satisfied: nbformat in /srv/conda/envs/notebook/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.5.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.8.0)
# Requirement already satisfied: jupyterlab-pygments in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
# Requirement already satisfied: tinycss2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.1.1)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: lxml in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.9.1)
# Requirement already satisfied: nbclient>=0.5.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.13)
# Requirement already satisfied: defusedxml in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.8.4)
# Requirement already satisfied: jsonschema>=2.6 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (4.16.0)
# Requirement already satisfied: fastjsonschema in /srv/conda/envs/notebook/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.16.1)
# Requirement already satisfied: argon2-cffi-bindings in /srv/conda/envs/notebook/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (21.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.18.1)
# Requirement already satisfied: cffi>=1.0.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.3.2.post1)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (0.5.1)
# Requirement already satisfied: pycparser in /srv/conda/envs/notebook/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipympl) (2.21)
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.3
# Collecting feature-engine
#   Using cached feature_engine-1.5.2-py2.py3-none-any.whl (290 kB)
# Requirement already satisfied: scipy>=1.4.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from feature-engine) (1.9.1)
# Requirement already satisfied: statsmodels>=0.11.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from feature-engine) (0.13.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from feature-engine) (1.1.2)
# Requirement already satisfied: numpy>=1.18.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from feature-engine) (1.22.4)
# Requirement already satisfied: pandas>=1.0.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from feature-engine) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.0.3->feature-engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas>=1.0.3->feature-engine) (2022.2.1)
# Requirement already satisfied: joblib>=1.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn>=1.0.0->feature-engine) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from scikit-learn>=1.0.0->feature-engine) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from statsmodels>=0.11.1->feature-engine) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from statsmodels>=0.11.1->feature-engine) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from packaging>=21.3->statsmodels>=0.11.1->feature-engine) (3.0.9)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels>=0.11.1->feature-engine) (1.16.0)
# Installing collected packages: feature-engine
# Successfully installed feature-engine-1.5.2

# %% [markdown]
# ## Importing Packages

# %%
from notebook.services.config import ConfigManager
import warnings
c = ConfigManager()
c.update('notebook', {"CodeCell": {"cm_config": {"autoCloseBrackets": True}}})
warnings.filterwarnings("ignore")

# %%
{
    "codeCellConfig": {
        "codeFolding": True
    }
}

# %%
from glob import glob
import os, sys
import re
from os import listdir
import glob
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
import rasterio as rio
import fiona
import rasterio.mask
from rasterio.plot import show
from rasterio import plot as rp
import pandas as pd
import math
import geopandas as gpd
import seaborn as sns
from IPython.display import Image
from shapely.geometry import mapping
import rioxarray as rxr
import xarray as xr
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
import numpy as np
import matplotlib
from matplotlib.colors import ListedColormap
import plotly.graph_objects as go
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, cross_val_score
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay, roc_auc_score
from sklearn.metrics import jaccard_score, log_loss, balanced_accuracy_score, make_scorer, f1_score
from imblearn.ensemble import BalancedRandomForestClassifier, EasyEnsembleClassifier
from sklearn.model_selection import RandomizedSearchCV, cross_val_predict, GridSearchCV, cross_validate
from sklearn.svm import SVC
from tqdm import tqdm
from sklearn import utils
from imblearn.over_sampling import SMOTE
import pickle
from xgboost import XGBClassifier
import scipy.ndimage
from scipy.stats import ks_2samp
from scipy import stats
np.seterr(divide='ignore', invalid='ignore')
pd.options.display.max_columns = 100
# %matplotlib inline

# %% [markdown]
# ## Import Image and Ground Reference

# %%
img = rio.open("./Input_Images/PlanetMosaic_04Nov2022_Warp_FromDrone3m.tif")
pbl = rio.open("./Input_Images/PlanetMosaic_04Nov2022_Class_FromDrone3m.tif")
# pbl = rio.open("./Input_Images/PlanetMosaic_04Nov2022_Class_FromDrone3m.tif")
tiff_extent = [img.bounds[0], img.bounds[2], img.bounds[1], img.bounds[3]]
print('Image bands', img.count)
print('Probability bands', pbl.count)
print('Image crs: ', img.crs)
print('Probability crs: ', pbl.crs)
print('Cols', img.width)
print('Rows', img.height)
noBands = img.count

def apply_mask_class(pb):
    pb = np.where(pb == -1, np.nan, pb)
    return pb

pbl_r = pbl.read(1)
pbl_r = apply_mask_class(pbl_r)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6), tight_layout=True)
show(img, ax=ax1, extent=tiff_extent , transform=img.transform)
show(pbl_r, ax=ax2, extent=tiff_extent , transform=img.transform)
plt.show()
# Out:
# Image bands 8
# Probability bands 1
# Image crs:  EPSG:32636
# Probability crs:  EPSG:32636
# Cols 173
# Rows 177

# %%
image = []
for i in range(1,noBands+1):
    image.append(apply_mask_class(img.read(i)/10000))

image.append(pbl_r)
image_r = np.stack(image, axis=0)
image_r.shape
# Out:
# (9, 177, 173)

# %%
image_df = pd.DataFrame(image_r.reshape([noBands+1,-1]).T, \
                        columns=['B1','Blue','G1','Green','Yellow','Red','RedEdge','NIR','Class'])
image_df = image_df[['Blue','Green','Red', 'NIR','Class']]
print('Data Matrix (Original) ', image_df.shape)
# image_df = image_df[(image_df.T != -1).all()]
# image_df = image_df[(image_df.T != 3).any()]
image_df.dropna(axis=0, how='any', inplace=True)
print('Data Matrix (Cleaned) ', image_df.shape)
image_df['Class'] = image_df["Class"].astype('uint8').astype('category')
image_df.dtypes
# Out:
# Data Matrix (Original)  (30621, 5)
# Data Matrix (Cleaned)  (299, 5)
# Blue      float64
# Green     float64
# Red       float64
# NIR       float64
# Class    category
# dtype: object

# %%
image_df["Class"].value_counts()
# Out:
# 1    100
# 2    100
# 0     99
# Name: Class, dtype: int64

# %%
sampledData = utils.shuffle(image_df.groupby("Class").head(99), random_state=8)
sampledData["Class"].value_counts()
# Out:
# 0    99
# 1    99
# 2    99
# Name: Class, dtype: int64

# %% [markdown]
# ## Common functions for data preparation and generating results

# %%
# matplotlib.rc_file_defaults()
# %matplotlib inline

# Function for classification outcomes
def classificationDetails(model, trainData, trainLabels, testData, testLabels, predLabels, predProb, modelName):
    
    # Accuracy of the model
    accuracy = accuracy_score(testLabels, predLabels)
    print('Classification Accuracy of the model: {:.2f}%'.format(accuracy*100))
    
    jaccard = jaccard_score(testLabels, predLabels, average=None)
    jaccard = np.round(jaccard, 4)
    print('Jaccard Score of the model: ', jaccard)
    
    ovr_auc = roc_auc_score(testLabels, predProb, labels = model.classes_, multi_class = 'ovr', average = None)
    ovr_auc = np.round(ovr_auc, 4)
    print('ROC AUC (OvR) Score of the model: ', ovr_auc)
    
    # Confusion matrix
    print("Confusion Matrix")
    target_names = ["Heterotheca", "Outgroup", "Soil"]
    cm = confusion_matrix(testLabels, predLabels, labels = model.classes_, normalize='true')
    cm = cm * 100
    # cm = confusion_matrix(testLabels, predLabels, labels = model.classes_)
    # print(matrix)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=target_names)
    # model.classes_
    plt.figure(figsize=(3,3))
    plt.rcParams.update({'font.size': 14})
    disp.plot(cmap=plt.cm.Blues,values_format='.2f')
    plt.tight_layout()
    plt.savefig('./Outputs/Stats/ConfusionMatrix_'+modelName+'.png', dpi = 300, bbox_inches = 'tight')
    
    # Classification Report
    print("\nClassification Report")
    report = classification_report(testLabels, predLabels, target_names=target_names, digits=3)
    print(report)
    report = classification_report(testLabels, predLabels, target_names=target_names, digits=3, output_dict=True)
    report.update({"accuracy": {"precision": None, "recall": None, "f1-score": report["accuracy"], "support": report['macro avg']['support']}})
    report.update({"jaccard": {"precision": jaccard[0], "recall": jaccard[1], "f1-score": jaccard[2], "support": None}})
    report.update({"OvR_AUC": {"precision": ovr_auc[0], "recall": ovr_auc[1], "f1-score": ovr_auc[2], "support": None}})
    reportDF = pd.DataFrame(report).transpose()
    # reportDF.to_csv('./Outputs/Stats/classReport_'+modelName+'.csv')
    return

# %%
def applyFullImage(imageName, datasetType, model, modelName):
    # Image loading and size checking
    img_val = rio.open(imageName+'.tif')
    head, tail = os.path.split(imageName+'.tif')
    fname, fext = os.path.splitext(tail)
    tiff_extent = [img_val.bounds[0], img_val.bounds[2], img_val.bounds[1], img_val.bounds[3]]
    print('Image bands', img_val.count)
    print('Image crs: ', img_val.crs)
    rows = img_val.height
    cols = img_val.width
    # print('Cols', cols)
    # print('Rows', rows)
    noBandsVal = img_val.count
    im1 = img_val.read(1)
    # Converting image to dataframe
    img_r = []
    for i in range(1, noBandsVal+1):
        temp = img_val.read(i)
        img_r.append(temp/10000)

    img_r = np.stack(img_r, axis=0)
    img_df = pd.DataFrame(img_r.reshape([noBands,-1]).T, \
                          columns=['B1','Blue','G1','Green','Yellow','Red','RedEdge','NIR'])
    img_df = img_df[['Blue','Green','Red','NIR']]

    img_df = img_df.replace(-1, np.nan)
    img_df = img_df.replace(0, np.nan)
    
    if datasetType == '4Bands':
        img_df = img_df
    else:
        img_df = computeIndices(img_df)
    
    img_df = img_df.replace(np.nan, -1)
    
    # Predict probability (3 bands generated)
    # band 0 - Heterotheca
    # band 1 - Outgroup
    # band 2 - Soil
    y_pred_prob = model.predict_proba(img_df)
    
    def apply_mask_border(img, gt):
        img = np.where(gt == 0, np.nan, img)
        return img
        
    y_pred_prob_reshape = np.zeros((3, rows, cols))
    y_pred_prob_reshape[0, :, :] = y_pred_prob[:,0].reshape(rows, cols)
    y_pred_prob_reshape[1, :, :] = y_pred_prob[:,1].reshape(rows, cols)
    y_pred_prob_reshape[2, :, :] = y_pred_prob[:,2].reshape(rows, cols)
    
    for i in range(0, 3):
        y_pred_prob_reshape[i, :, :] = apply_mask_border(y_pred_prob_reshape[i, :, :], im1)
    
    # Predict classes
    y_pred_val = model.predict(img_df) # Default classification threshold is 0.5
    y_pred_val = y_pred_val.astype('float32')
    # im1 = im1.reshape([1, -1]).T
    # y_pred_val = y_pred_val.reshape([1, -1]).T
    
    # background_mask = im1 == -1
    # y_pred_val[background_mask] = -1
    
    # y_pred_val = model.predict_proba(img_df)
    # y_pred_val = (y_pred_val[:,0] >= 0.65).astype(int)
    # y_pred_val = model.predict(img_df) # Default classification threshold is 0.5
        
    y_pred_val_reshape = np.reshape(y_pred_val, (1, rows, cols))
    y_pred_val_reshape = apply_mask_border(y_pred_val_reshape, im1)
    
    # Removing isolated pixels from the classified image
    # tmp = scipy.ndimage.convolve(y_pred_val_reshape, np.ones((3,3)), mode='constant')
    # y_pred_val_reshape = np.logical_and(tmp >= 4, y_pred_val_reshape).astype(np.float32)
    
    # y_pred_val_reshape = np.reshape(y_pred_val_reshape, (1, rows, cols))
    # y_pred_prob_reshape = np.reshape(y_pred_prob[:,0], (1, rows, cols)) 
    
    # def apply_mask_image(img, gt):
    #     img = np.where(gt == -1, np.nan, img)
    #     return img
    
    meta = img_val.meta.copy()
    meta.update({'count':1})
    meta.update({'dtype':'float32'})
    meta.update({'nodata':-1})
    metaprob = img_val.meta.copy()
    metaprob.update({'count':3})
    metaprob.update({'dtype':'float32'})
    metaprob.update({'nodata':-1})
    
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12,9), tight_layout=True)
    show(img_val, ax=ax1, extent=tiff_extent , transform=img_val.transform)
    show(y_pred_val_reshape, ax=ax2, extent=tiff_extent , transform=img_val.transform)
    show(y_pred_prob_reshape, ax=ax3, extent=tiff_extent , transform=img_val.transform)
    plt.show()
    
    outfilename = './Outputs/Images/' + fname + '_' + datasetType + '_' + modelName + '.tif'
    outprobfilename = './Outputs/Images/' + fname + '_' + datasetType + '_' + modelName + '_Prob.tif'
    # with rio.open(outfilename, 'w', **meta) as out:
    #     out.write(y_pred_val_reshape)
    # with rio.open(outprobfilename, 'w', **metaprob) as outprob:
    #     outprob.write(y_pred_prob_reshape)
    return

# %%
def plot_feature_importance(importance, names, model_type, modelName):
    #Create arrays from feature importance and feature names
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    #Create a DataFrame using a Dictionary
    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)
    
    #Sort the DataFrame in order decreasing feature importance
    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)

    #Define size of bar plot
    plt.figure(figsize=(8,6))
    #Plot Searborn bar chart
    sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])
    #Add chart labels
    plt.title(model_type + 'Feature Importance')
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature Names')
    # plt.savefig('./Outputs/Stats/FeatureImportance_'+modelName+'.png', dpi = 300, bbox_inches = 'tight')
    return

# %%
# Final index - NDYI, SAVI, EBI, BI, NBRRI
def computeIndices(df):
    df1 = df[['Blue', 'Green', 'Red', 'NIR']]
    # df1['SlopeGB'] = df["Green"] - df["Blue"]
    df1['NDYI'] = (df["Green"] - df["Blue"])/(df["Green"] + df["Blue"])
    # df1['NDVI'] = (df["NIR"] - df["Red"]) / (df["NIR"] + df["Red"])
    df1['SAVI'] = (2 * (df["NIR"] - df["Red"])) / (df["NIR"] + df["Red"] + 1)
    # df1['VDVI'] = (2 * df["Green"] - df["Red"] - df["Blue"]) / (2 * df["Green"] + df["Red"] + df["Blue"])
    # df1['MGRVI'] = (np.power(df["Green"], 2) - np.power(df["Red"], 2)) / (np.power(df["Green"], 2) + np.power(df["Red"], 2))
    df1['EBI'] = (df[["Blue", "Green", "Red"]].sum(axis=1)) / ((df["Green"] / df["Blue"]) * (df["Red"] - df["Blue"] + 1))
    # df1['GNDVI'] = (df["NIR"] - df["Green"]) / (df["NIR"] + df["Green"])
    df1['BI'] = np.power(((np.power(df["Red"], 2) + np.power(df["Green"],2) + np.power(df["Blue"],2))/3),0.5)
    df1['NBRRI'] = (df["Red"] - df["Blue"])/(df["Red"] + df["Blue"])
    # Blue-wide dynamic range vegetation index (BWDRVI)
    # df1['SI'] = (df["Red"] - df["Blue"])/(df["Red"] + df["Blue"])
    # Saturation index has same formula as NBRRI, hence we are using NBRRI
    # hsv = matplotlib.colors.rgb_to_hsv(df[['Red','Green','Blue']])
    # hsv = np.round(hsv, 6)
    # hsv = pd.DataFrame(hsv, index=df.index, columns=['Hue', 'Saturation', 'Value'])
    # df1 = pd.concat([df1, hsv[['Hue', 'Saturation']]], axis=1)
    return df1

# %% [markdown]
# ## Multiclass Accuracy Curves (Common Functions)

# %%
def calculate_tpr_fpr(y_real, y_pred):
    '''
    Calculates the True Positive Rate (tpr) and the True Negative Rate (fpr) based on real and predicted observations
    
    Args:
        y_real: The list or series with the real classes
        y_pred: The list or series with the predicted classes
        
    Returns:
        tpr: The True Positive Rate of the classifier
        fpr: The False Positive Rate of the classifier
    '''
    
    # Calculates the confusion matrix and recover each element
    cm = confusion_matrix(y_real, y_pred)
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
    TP = cm[1, 1]
    
    # Calculates tpr and fpr
    tpr =  TP/(TP + FN) # sensitivity - true positive rate
    fpr = 1 - TN/(TN+FP) # 1-specificity - false positive rate
    
    return tpr, fpr

# %%
def get_all_roc_coordinates(y_real, y_proba):
    '''
    Calculates all the ROC Curve coordinates (tpr and fpr) by considering each point as a threshold for the predicion of the class.
    
    Args:
        y_real: The list or series with the real classes.
        y_proba: The array with the probabilities for each class, obtained by using the `.predict_proba()` method.
        
    Returns:
        tpr_list: The list of TPRs representing each threshold.
        fpr_list: The list of FPRs representing each threshold.
    '''
    tpr_list = [0]
    fpr_list = [0]
    for i in range(len(y_proba)):
        threshold = y_proba[i]
        y_pred = y_proba >= threshold
        tpr, fpr = calculate_tpr_fpr(y_real, y_pred)
        tpr_list.append(tpr)
        fpr_list.append(fpr)
    return tpr_list, fpr_list

# %%
def plot_roc_curve(tpr, fpr, scatter = True, ax = None):
    '''
    Plots the ROC Curve by using the list of coordinates (tpr and fpr).
    
    Args:
        tpr: The list of TPRs representing each coordinate.
        fpr: The list of FPRs representing each coordinate.
        scatter: When True, the points used on the calculation will be plotted with the line (default = True).
    '''
    if ax == None:
        plt.figure(figsize = (5, 5))
        ax = plt.axes()
    
    if scatter:
        sns.scatterplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = [0, 1], y = [0, 1], color = 'green', ax = ax)
    plt.xlim(-0.05, 1.05)
    plt.ylim(-0.05, 1.05)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")

# %% [markdown]
# ## OvR ROC Curves

# %%
def OvR_ROC(model, X_test, y_test, y_proba, datasetType, modelName):
    # Plots the Probability Distributions and the ROC Curves One vs Rest
    plt.figure(figsize = (12, 8))
    bins = [i/20 for i in range(20)] + [1]
    classes = model.classes_
    roc_auc_ovr = {}
    for i in range(len(classes)):
        # Gets the class
        c = classes[i]

        # Prepares an auxiliar dataframe to help with the plots
        df_aux = X_test.copy()
        df_aux['class'] = [1 if y == c else 0 for y in y_test]
        df_aux['prob'] = y_proba[:, i]
        df_aux = df_aux.reset_index(drop = True)

        # Plots the probability distribution for the class and the rest
        ax = plt.subplot(2, 3, i+1)
        sns.histplot(x = "prob", data = df_aux, hue = 'class', color = 'b', ax = ax, bins = bins)
        ax.set_title(c)
        ax.legend([f"Class: {c}", "Rest"])
        ax.set_xlabel(f"P(x = {c})")

        # Calculates the ROC Coordinates and plots the ROC Curves
        ax_bottom = plt.subplot(2, 3, i+4)
        tpr, fpr = get_all_roc_coordinates(df_aux['class'], df_aux['prob'])
        plot_roc_curve(tpr, fpr, scatter = False, ax = ax_bottom)
        ax_bottom.set_title("ROC Curve OvR")

        # Calculates the ROC AUC OvR
        roc_auc_ovr[c] = roc_auc_score(df_aux['class'], df_aux['prob'])
    plt.tight_layout()
    
    # Displays the ROC AUC for each class
    avg_roc_auc = 0
    i = 0
    for k in roc_auc_ovr:
        avg_roc_auc += roc_auc_ovr[k]
        i += 1
        print(f"{k} ROC AUC OvR: {roc_auc_ovr[k]:.4f}")
    print(f"average ROC AUC OvR: {avg_roc_auc/i:.4f}")
    
    # plt.savefig('./Outputs/OneVsRest_ROC_Curves_'+datasetType+'_'+modelName+'.png', dpi = 300, bbox_inches = 'tight')
    return None

# %% [markdown]
# ## Correlation amongst factors

# %%
import seaborn as sns

testDF = computeIndices(image_df.loc[:, image_df.columns != "Class"])
pearsoncorr = testDF.corr(method='pearson')

plt.figure(figsize=(12, 10))
sns.heatmap(pearsoncorr, xticklabels=pearsoncorr.columns, 
           yticklabels=pearsoncorr.columns, 
           cmap='RdBu_r', annot=True,linewidth=0.5)
plt.savefig('CorrelationPlot_Factors_Planet_newTrained.png', bbox_inches='tight', dpi=300, transparent=False)

# %% [markdown]
# ## Train - Test Split

# %%
X = sampledData.iloc[: , :4]
y = sampledData.iloc[: , 4]

withIndices = input('Do you want indices ? (y/n)')
if withIndices == 'y':
    X = computeIndices(X)
    datasetType = str(X.shape[1]) + 'Bands'
else:
    datasetType = '4Bands'
    X = X

# shape = X.shape  # For last execution random_state = 10
# noNewBands = shape[1]
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=1)

# Two-sample Kolmogorov-Smirnov test for checking the train and test distribution
ks2_test = ks_2samp(y_train, y_test)
print(ks2_test)

train_test_data = './Outputs/TrainTestData/' + datasetType + '_train_test_data_newTrained.xlsx'

# with pd.ExcelWriter(train_test_data, engine="openpyxl") as writer:
#     tempTrnDF = pd.concat([X_train, y_train], axis=1)
#     tempTrnDF.to_excel(writer, sheet_name='TrainData', index=True, header=True)
#     tempTstDF = pd.concat([X_test, y_test], axis=1)
#     tempTstDF.to_excel(writer, sheet_name='TestData', index=True, header=True)
# writer=None
# Out:
# Do you want indices ? (y/n) y
# KstestResult(statistic=0.0, pvalue=1.0)

# %%
# Test Image Name
imageName = 'PlanetMosaic_04Nov2022_Warp_FromDrone3m'

# %%
import sklearn
sklearn.metrics.get_scorer_names()
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'matthews_corrcoef',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_absolute_percentage_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'rand_score',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'top_k_accuracy',
#  'v_measure_score']

# %% [markdown]
# ## Basic Random Forest

# %%
clf = RandomForestClassifier(n_estimators=60, max_depth=3, n_jobs=-1, random_state = 10)
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=3)

# evaluate model
# scores = cross_val_score(clf, X_train, y_train, cv=cv, n_jobs=-1)
# summarize performance
# print('Mean ROC AUC: %.3f (%.3f)' % (np.mean(scores), np.std(scores)))
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=60, n_jobs=-1, random_state=10)

# %%
y_pred = clf.predict(X_test)
y_proba = clf.predict_proba(X_test)
modelName = input("Input model name for saving results")
# Out:
# Input model name for saving results Model_RF_NoHPT_newTrained

# %%
# Classification Results
classificationDetails(clf, X_train, y_train, X_test, y_test, y_pred, y_proba, datasetType + '_' + modelName)
# Out:
# Classification Accuracy of the model: 76.67%
# Jaccard Score of the model:  [0.6316 0.6    0.6316]
# ROC AUC (OvR) Score of the model:  [0.9211 0.9011 0.9528]
# Confusion Matrix
#
# Classification Report
#               precision    recall  f1-score   support
#
#  Heterotheca      0.750     0.800     0.774        30
#     Outgroup      0.808     0.700     0.750        30
#         Soil      0.750     0.800     0.774        30
#
#     accuracy                          0.767        90
#    macro avg      0.769     0.767     0.766        90
# weighted avg      0.769     0.767     0.766        90

# %%
# Pickle Save
dumpName = './Outputs/Models/' + datasetType + '_' + modelName + '.pkl'
pickle.dump(clf, open(dumpName, 'wb'))

# Load trained model
# clf = pickle.load(open(dumpName, 'rb'))
# y_pred = clf.predict(X_test)

# %%
# Apply basic model on full image
# matplotlib.rc_file_defaults()
import seaborn as sns
applyFullImage(imageName, datasetType, clf, modelName)
OvR_ROC(clf, X_test, y_test, y_proba, datasetType, modelName)
# Out:
# Image bands 8
# Image crs:  EPSG:32636
# 0 ROC AUC OvR: 0.9211
# 1 ROC AUC OvR: 0.9011
# 2 ROC AUC OvR: 0.9528
# average ROC AUC OvR: 0.9250

# %% [markdown]
# ## Feature Importance

# %%
feature_list = list(X_train.columns)
print('Feature List', feature_list)
importances = list(clf.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Feature List ['Blue', 'Green', 'Red', 'NIR', 'NDYI', 'SAVI', 'EBI', 'BI', 'NBRRI']
# Variable: Blue                 Importance: 0.19
# Variable: Red                  Importance: 0.18
# Variable: EBI                  Importance: 0.15
# Variable: BI                   Importance: 0.13
# Variable: SAVI                 Importance: 0.12
# Variable: Green                Importance: 0.07
# Variable: NDYI                 Importance: 0.07
# Variable: NBRRI                Importance: 0.06
# Variable: NIR                  Importance: 0.04

# %%
import seaborn as sns
plt.figure(figsize=(3,2))
plot_feature_importance(clf.feature_importances_,X.columns,'Random Forest ', modelName)
# sns = None
# matplotlib.rc_file_defaults()

# %%
# importance = clf.feature_importances_
# for i,v in enumerate(importance):
#     print('Feature: %0d, Score: %.5f' % (i,v))
# # plot feature importance
# plt.bar([x for x in range(len(importance))], importance)
# plt.show()

# %matplotlib inline
# Set the style
# fig, ax = plt.subplots(figsize=(6, 4))
plt.figure(figsize=(7,5))
plt.style.use('fivethirtyeight')

# list of index locations for plotting
x_values = list(range(len(importances)))

# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');
plt.tight_layout()

# %% [markdown]
# ## RF Hyperparameter Tuning

# %%
# For old execution random_state = 0

rf_base = RandomForestClassifier(random_state=10, n_jobs=-1)
# rf_base = XGBClassifier(random_state=0, n_jobs=-1)

n_estimators = [int(x) for x in np.arange(20, 65, 5)]
# n_estimators = [int(x) for x in np.arange(10, 65, 10)] % Previous Execution
# np.linspace(start = 20, stop = 100, num = 50)
max_depth = [int(x) for x in np.linspace(2, 3, num = 2)]
max_features = ['log2', 'sqrt']
min_samples_split = [3, 5, 8, 10]
bootstrap = [True, False]
criterion=['gini', 'entropy', 'log_loss']

# random_grid = {'n_estimators': n_estimators, 'max_depth': max_depth, 'max_features':max_features, \
#                'criterion': criterion}

random_grid = {'n_estimators': n_estimators, 'max_depth': max_depth, 'max_features':max_features, \
               'min_samples_split':min_samples_split, 'bootstrap': bootstrap, 'criterion': criterion}

print(random_grid)
# Out:
# {'n_estimators': [20, 25, 30, 35, 40, 45, 50, 55, 60], 'max_depth': [2, 3], 'max_features': ['log2', 'sqrt'], 'min_samples_split': [3, 5, 8, 10], 'bootstrap': [True, False], 'criterion': ['gini', 'entropy', 'log_loss']}

# %%
cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=3, random_state=1)

scoring = make_scorer(log_loss, greater_is_better=False, needs_proba=True)
rf_random = RandomizedSearchCV(estimator = rf_base, param_distributions = random_grid,
                               n_iter=300, cv = cv, error_score='raise', random_state=10,
                               scoring = scoring, verbose=1, n_jobs = -1)
rf_random.fit(X_train, y_train)
# Out:
# Fitting 15 folds for each of 300 candidates, totalling 4500 fits
# RandomizedSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=5, random_state=1),
#                    error_score='raise',
#                    estimator=RandomForestClassifier(n_jobs=-1, random_state=10),
#                    n_iter=300, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': [2, 3],
#                                         'max_features': ['log2', 'sqrt'],
#                                         'min_samples_split': [3, 5, 8, 10],
#                                         'n_estimators': [20, 25, 30, 35, 40, 45,
#                                                          50, 55, 60]},
#                    random_state=10,
#                    scoring=make_scorer(log_loss, greater_is_better=False, needs_proba=True),
#                    verbose=1)

# %%
print(rf_random.best_params_)
y_pred = rf_random.predict(X_test)
y_proba = rf_random.predict_proba(X_test)
modelName = input("Input model name for saving results")
# Out:
# {'n_estimators': 55, 'min_samples_split': 5, 'max_features': 'sqrt', 'max_depth': 3, 'criterion': 'gini', 'bootstrap': True}
# Input model name for saving results Model_RF_HPT_newTrained

# %%
bestmodel = rf_random.best_estimator_
rf_new = RandomForestClassifier(n_estimators=bestmodel.n_estimators, 
                                max_depth=bestmodel.max_depth, 
                                criterion= bestmodel.criterion, 
                                max_features= bestmodel.max_features, random_state=10, n_jobs=-1)
rf_new.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=55, n_jobs=-1, random_state=10)

# %%
feature_list = list(X_train.columns)
print('Feature List', feature_list)
importances = list(rf_new.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Feature List ['Blue', 'Green', 'Red', 'NIR', 'NDYI', 'SAVI', 'EBI', 'BI', 'NBRRI']
# Variable: Blue                 Importance: 0.18
# Variable: Red                  Importance: 0.18
# Variable: EBI                  Importance: 0.16
# Variable: SAVI                 Importance: 0.13
# Variable: BI                   Importance: 0.12
# Variable: Green                Importance: 0.07
# Variable: NDYI                 Importance: 0.07
# Variable: NBRRI                Importance: 0.06
# Variable: NIR                  Importance: 0.04

# %%
import seaborn as sns
plt.figure(figsize=(4,3))
plot_feature_importance(rf_new.feature_importances_,X.columns,'Random Forest ', modelName)
# sns = None
# matplotlib.rc_file_defaults()

# %%
# Classification Results
matplotlib.rc_file_defaults()
classificationDetails(rf_random, X_train, y_train, X_test, y_test, y_pred, y_proba, datasetType + '_' + modelName)
# Out:
# Classification Accuracy of the model: 77.78%
# Jaccard Score of the model:  [0.6579 0.6    0.6486]
# ROC AUC (OvR) Score of the model:  [0.9233 0.9022 0.9539]
# Confusion Matrix
#
# Classification Report
#               precision    recall  f1-score   support
#
#  Heterotheca      0.758     0.833     0.794        30
#     Outgroup      0.808     0.700     0.750        30
#         Soil      0.774     0.800     0.787        30
#
#     accuracy                          0.778        90
#    macro avg      0.780     0.778     0.777        90
# weighted avg      0.780     0.778     0.777        90

# %%
# Pickle Save
dumpName = './Outputs/Models/' + datasetType + '_' + modelName + '.pkl'
pickle.dump(rf_random, open(dumpName, 'wb'))

# Load trained model
# rf_random = pickle.load(open(dumpName, 'rb'))
# y_pred = rf_random.predict(X_test)

# %%
# Apply basic model on full image
# matplotlib.rc_file_defaults()
import seaborn as sns
applyFullImage(imageName, datasetType, rf_random, modelName)
OvR_ROC(rf_random, X_test, y_test, y_proba, datasetType, modelName)
# Out:
# Image bands 8
# Image crs:  EPSG:32636
# 0 ROC AUC OvR: 0.9233
# 1 ROC AUC OvR: 0.9022
# 2 ROC AUC OvR: 0.9539
# average ROC AUC OvR: 0.9265

# %%
from sklearn.inspection import (partial_dependence, PartialDependenceDisplay)
modelName = 'Model_RF_HPT'
# Load trained model
rf_random = pickle.load(open('./Outputs/Models/9Bands_Model_RF_HPT_newTrained.pkl', 'rb'))

var = ['Red', 'Blue', 'EBI', 'SAVI', 'BI', 'Green']#, 'Saturation', 'NDYI', 'MGRVI']

n_cols = 2
n_rows = int(len(var)/n_cols)
fig, ax = plt.subplots(n_rows, n_cols, figsize=(8, 10))
PartialDependenceDisplay.from_estimator(rf_random, X_train, var, target=0,\
                                        ax=ax, n_cols=n_cols, kind='both', centered=True, n_jobs=-1)
# PartialDependenceDisplay.from_estimator(rf_random, X_train, var, target=0, line_kw={"color": "red"},\
#                                         ax=ax, n_cols=n_cols, centered=True, n_jobs=-1)
# fig.suptitle('Partial Dependence Plots')
fig.suptitle('Individual Conditional Expectation Plots')
fig.tight_layout()

# plt.savefig('./Outputs/PDP_'+modelName+'.png', dpi=300, bbox_inches='tight')
plt.savefig('./Outputs/ICE_'+modelName+'.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Apply on Planet 1km x 1km grids of images
# - Parallel Processing

# %%
# Function for applying classification results on all images

def applyFullImageFolder(address):
    model = rf_random
    modelName = 'Model_RF_HPT_newTrained'
    datasetType = '9Bands'
    output_dir = os.path.dirname('./Planet_Images/')
    # Image loading and size checking
    head, tail = os.path.split(address)
    fname, fext = os.path.splitext(tail)
    img_val = rio.open(address)
    # print('Image bands', img_val.count)
    # print('Image crs: ', img_val.crs)
    rows = img_val.height
    cols = img_val.width
    # print('Cols', cols)
    # print('Rows', rows)
    noBandsVal = img_val.count
    im1 = img_val.read(1)
    
    # Converting image to dataframe
    img_r = []
    for i in range(1, noBandsVal+1):
        temp = img_val.read(i)
        img_r.append(temp/10000)

    img_r = np.stack(img_r, axis=0)
    img_df = pd.DataFrame(img_r.reshape([noBands,-1]).T, \
                          columns=['B1','Blue','G1','Green','Yellow','Red','RedEdge','NIR'])
    img_df = img_df[['Blue','Green','Red','NIR']]

    img_df = img_df.replace(-1, np.nan)
    img_df = img_df.replace(0, np.nan)
    
    if datasetType == '4Bands':
        img_df = img_df
    else:
        img_df = computeIndices(img_df)
    
    img_df = img_df.replace(np.nan, -1)
    
    # Predict probability (3 bands generated)
    # band 0 - Heterotheca
    # band 1 - Outgroup
    # band 2 - Soil
    y_pred_prob = model.predict_proba(img_df)
    
    def apply_mask_border(img, gt):
        img = np.where(gt == 0, np.nan, img)
        return img
        
    y_pred_prob_reshape = np.zeros((3, rows, cols))
    y_pred_prob_reshape[0, :, :] = y_pred_prob[:,0].reshape(rows, cols)
    y_pred_prob_reshape[1, :, :] = y_pred_prob[:,1].reshape(rows, cols)
    y_pred_prob_reshape[2, :, :] = y_pred_prob[:,2].reshape(rows, cols)
    
    for i in range(0, 3):
        y_pred_prob_reshape[i, :, :] = apply_mask_border(y_pred_prob_reshape[i, :, :], im1)
    
    # Predict classes
    # y_pred_val = model.predict(img_df) # Default classification threshold is 0.5
    # y_pred_val = y_pred_val.astype('float32')    
        
    # y_pred_val_reshape = np.reshape(y_pred_val, (1, rows, cols))
    # y_pred_val_reshape = apply_mask_border(y_pred_val_reshape, im1)
    
    # meta = img_val.meta.copy()
    # meta.update({'count':1})
    # meta.update({'dtype':'float32'})
    # meta.update({'nodata':-1})
    metaprob = img_val.meta.copy()
    metaprob.update({'count':3})
    metaprob.update({'dtype':'float32'})
    metaprob.update({'nodata':-1})
    
    # fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12,9), tight_layout=True)
    # show(img_val, ax=ax1, extent=tiff_extent , transform=img.transform)
    # show(y_pred_val_reshape, ax=ax2, extent=tiff_extent , transform=img.transform)
    # show(y_pred_prob_reshape, ax=ax3, extent=tiff_extent , transform=img.transform)
    # plt.show()
    
    output_file = fname + '_' + datasetType + '_' + modelName + '_Prob.tif'
    outprobfilename = os.path.join(output_dir, output_file)
    with rio.open(outprobfilename, 'w', **metaprob) as outprob:
        outprob.write(y_pred_prob_reshape)
    return None

# %%
from multiprocessing import Pool
import os
import time

input_dir = os.path.dirname('./Planet_Images/')
pathFolder = sorted(glob.glob(input_dir + r'/*.tif'))

def main():
    workers = os.cpu_count()
    with Pool(workers) as p:
        p.map(applyFullImageFolder, pathFolder)
        p.close()
if __name__ == '__main__':
    main()

# %% [markdown]
# ## Zipping Results

# %%
import os
import zipfile    

def zipit(folders, zip_filename):
    zip_file = zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED)

    for folder in folders:
        for dirpath, dirnames, filenames in os.walk(folder):
            for filename in filenames:
                zip_file.write(
                    os.path.join(dirpath, filename),
                    os.path.relpath(os.path.join(dirpath, filename), os.path.join(folders[0], '../..')))

    zip_file.close()

folders = ["Ashdod_Image", "Input_Images", "Outputs"]

zipit(folders, "PlanetScope_Image_Results.zip")
